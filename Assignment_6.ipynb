# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51529/RL-LAB/blob/main/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):

    env = gym.make(env_name)

    print("\nEnvironment:", env_name)
    print("-" * 40)

    for episode in range(1, episodes + 1):

        state, info = env.reset()

        total_reward = 0
        steps = 0

        while True:

            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1

            state = next_state

            if terminated or truncated:
                break

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()


random_agent("CliffWalking-v1", 5)

random_agent("Taxi-v4", 5)
# Out:
# Environment: CliffWalking-v1
# ----------------------------------------
# Episode: 1
# Total Reward: -2350
# Average Reward: -8.67
#
# Episode: 2
# Total Reward: -43312
# Average Reward: -10.54
#
# Episode: 3
# Total Reward: -11573
# Average Reward: -10.73
#
# Episode: 4
# Total Reward: -12715
# Average Reward: -8.9
#
# Episode: 5
# Total Reward: -83221
# Average Reward: -10.69
#
#
# Environment: Taxi-v4
# ----------------------------------------
# Episode: 1
# Total Reward: -776
# Average Reward: -3.88
#
# Episode: 2
# Total Reward: -830
# Average Reward: -4.15
#
# Episode: 3
# Total Reward: -731
# Average Reward: -3.65
#
# Episode: 4
# Total Reward: -848
# Average Reward: -4.24
#
# Episode: 5
# Total Reward: -803
# Average Reward: -4.01
